# %%
import pandas as pd

df = pd.read_csv("test.csv")

df['date'] = pd.to_datetime(df['date'])
df['month'] = df['date'].dt.to_period('M')

# %%
df.head()
# Out:
#                                         Subject  \
# 0                          EnronOptions Update!
# 1                                  (No Subject)
# 2  Phone Screen  Interview - Shannon L. Burnham
# 3                         RE: My new work email
# 4                                           Bet
#
#                                                 body       date  \
# 0  EnronOptions Announcement\n\n\nWe have updated... 2010-05-10
# 1  Marc,\n\nUnfortunately, today is not going to ... 2010-07-29
# 2  When: Wednesday, June 06, 2001 10:00 AM-11:00 ... 2011-07-25
# 3  we were thinking papasitos (we can meet somewh... 2010-03-25
# 4  Since you never gave me the $20 for the last t... 2011-05-21
#
#                       from    month sentiment  score  msg_length  word_count
# 0     sally.beck@enron.com  2010-05  Positive      1         692         101
# 1      eric.bass@enron.com  2010-07  Positive      1         315          57
# 2     sally.beck@enron.com  2011-07   Neutral      0         150          21
# 3  johnny.palmer@enron.com  2010-03   Neutral      0         155          24
# 4  lydia.delgado@enron.com  2011-05  Positive      1         197          42

# %%
from nltk.sentiment import SentimentIntensityAnalyzer
import nltk

nltk.download('vader_lexicon')

sia = SentimentIntensityAnalyzer()

def get_sentiment(text):
    score = sia.polarity_scores(str(text))['compound']
    
    if score > 0.05:
        return "Positive"
    elif score < -0.05:
        return "Negative"
    else:
        return "Neutral"

df['sentiment'] = df['body'].apply(get_sentiment)
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\sharm\AppData\Roaming\nltk_data...

# %%
score_map = {
    "Positive":1,
    "Negative":-1,
    "Neutral":0
}

df['score'] = df['sentiment'].map(score_map)

# %%
employee_month_score = (
    df.groupby(['from','month'])['score']
    .sum()
    .reset_index()
)

# %%
top_positive = (
employee_month_score
.sort_values(['month','score'],ascending=[True,False])
.groupby('month')
.head(3)
)

# %%
top_negative = (
employee_month_score
.sort_values(['month','score'])
.groupby('month')
.head(3)
)

# %%
df['date'] = pd.to_datetime(df['date'])

neg = df[df['sentiment']=="Negative"]

# IMPORTANT STEP
neg = neg.sort_values(['from','date'])

flight_risk = (
    neg.groupby('from')
    .rolling('30D', on='date')['body']
    .count()
    .reset_index(name='neg_count')
)

flight_risk = flight_risk[flight_risk['neg_count'] >= 4]

flight_risk_employees = flight_risk['from'].unique()

# %%
df['msg_length'] = df['body'].str.len()
df['word_count'] = df['body'].str.split().apply(len)

# %%
features = df.groupby(['from','month']).agg({
'msg_length':'mean',
'word_count':'mean',
'body':'count',
'score':'sum'
}).reset_index()

features.rename(columns={'body':'msg_count'},inplace=True)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

X = features[['msg_length','word_count','msg_count']]
y = features['score']

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2)

model = LinearRegression()
model.fit(X_train,y_train)

pred = model.predict(X_test)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(x='sentiment',data=df)
# Out:
# <Axes: xlabel='sentiment', ylabel='count'>

# %%
df.groupby('month')['score'].sum().plot()
# Out:
# <Axes: xlabel='month'>
